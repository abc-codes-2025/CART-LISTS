# %% [markdown]
# LISTS

# %%
My_list = [101, 102, 103, 104]
print(My_list)
# Out:
# [101, 102, 103, 104]

# %% [markdown]
# LIST OPERATIONS
# 1. Append

# %%
My_list.append(105)
print(My_list)
# Out:
# [101, 102, 109, 109, 109, 109, 109, 109, 109, 109, 109, 109, 109, 109, 109, 109, 103, 104, 105, 105]

# %%
My_list.insert(2, 109)
print(My_list)
# Out:
# [101, 102, 109, 109, 109, 109, 109, 109, 109, 109, 109, 109, 109, 109, 109, 109, 103, 104, 105, 105, 105, 105, 105, 105, 105, 105, 105, 105, 105, 105, 105, 105, 105, 105, 105]

# %%
My_list.pop
print(My_list)
# Out:
# [101, 102, 109, 109, 109, 109, 109, 109, 109, 109, 109, 109, 109, 109, 109, 103, 104, 105, 105, 105, 105, 105, 105, 105, 105, 105, 105, 105, 105, 105, 105, 105, 105, 105]

# %%
My_list.remove(105)
print(My_list)
# Out:
# [101, 102, 109, 109, 109, 109, 109, 109, 109, 109, 109, 109, 109, 109, 109, 109, 103, 104, 105]

# %%
print("Welcome to SSE mart")
print("="*20)

shopping_cart = ["Shoes" , "Chips" , "Books" , "Games"]
print(shopping_cart)
print("="*40)

add_item = "tshirt"
shopping_cart.append(add_item)
print(shopping_cart)
print("="*40)

remove_item = "Books"
shopping_cart.remove(remove_item)
print(shopping_cart)
print ("="*40)
# Out:
# Welcome to SSE mart
# ...
# ['Shoes', 'Chips', 'Books', 'Games']
# ...
# ['Shoes', 'Chips', 'Books', 'Games', 'tshirt']
# ...
# ['Shoes', 'Chips', 'Games', 'tshirt']
# ...

# %%
print("Welcome to SPOTIFY Liked Songs")
print("="*20)

Liked_songs = ["A.R.Rahman" , "Pritam" , "M.M.Keeravani" , "Shankar Mahadevan"]
print(Liked_songs)
print("="*40)

add_item = "tshirt"
Liked_songs.append(add_item)
print(Liked_songs)
print("="*40)

remove_item = "Pritam"
Liked_songs.remove(remove_item)
print(Liked_songs)
print ("="*40)
# Out:
# Welcome to SPOTIFY Liked Songs
# ...
# ['A.R.Rahman', 'Pritam', 'M.M.Keeravani', 'Shankar Mahadevan']
# ...
# ['A.R.Rahman', 'Pritam', 'M.M.Keeravani', 'Shankar Mahadevan', 'tshirt']
# ...
# ['A.R.Rahman', 'M.M.Keeravani', 'Shankar Mahadevan', 'tshirt']
# ...
